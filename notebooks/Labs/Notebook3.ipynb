# %% [markdown]
# # Lists

# %%
ages = [30,31,32,33]

# %% [markdown]
# ## Index with 0

# %%
ages[0]
# Out:
# 30

# %%
ages[-1]
# Out:
# 33

# %% [markdown]
# ## Manipulating Lists

# %%
ages + [21]
# Out:
# [30, 31, 32, 33, 21]

# %%
ages.append(35)

# %%
ages
# Out:
# [30, 31, 32, 33, 35]

# %%
del(ages[-1])

# %%
ages
# Out:
# [30, 31, 32, 33]

# %% [markdown]
# # Nested Lists

# %%
nested = [
    ["jhon",30],
    ["Maria",31],
    ["Steve",32]
         ]

# %%
nested
# Out:
# [['jhon', 30], ['Maria', 31], ['Steve', 32]]

# %%
nested[0][0]
# Out:
# 'jhon'

# %% [markdown]
# # Creating a Copy

# %%
z = nested[:]

# %%
z
# Out:
# [['jhon', 30], ['Maria', 31], ['Steve', 32]]
