# %% [markdown]
# ## Functions

# %%
def saludar(nombre): 
    print(f"Hola, {nombre}!")

# %%
saludar("Mundo")
# Out:
# Hola, Mundo!

# %%
saludar("Python")
# Out:
# Hola, Python!

# %%
def fibonacci(n): 
    if n <= 0: 
        return 0
    elif n == 1: 
        return 1
    else: 
        return fibonacci(n-1) + fibonacci(n-2)

# %%
fibonacci(10)  # 55
# Out:
# 55

# %%
name = "Juan"

# %%
name.islower()
# Out:
# False

# %%
import math

# %%
fibonacci(90)
