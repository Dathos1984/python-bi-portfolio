# %% [markdown]
# # Data Types

# %% [markdown]
# ## String

# %%
'Hola mundo'
# Out:
# 'Hola mundo'

# %%
y = 'Hola mundo'

# %%
print(y)
# Out:
# Hola mundo

# %% [markdown]
# ## Int

# %%
x= 5

# %% [markdown]
# ## Float

# %%
z = 2.5

# %%
type (z)
# Out:
# float

# %% [markdown]
# ## Bollean

# %%
x = True

# %%
y = True

# %%
print(x)
# Out:
# True

# %% [markdown]
# # Calculations

# %%
x = 3
y = 3.2
z = x + y
z
# Out:
# 6.2

# %%
type(z)
# Out:
# float
