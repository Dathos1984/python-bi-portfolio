# %% [markdown]
# # Loops

# %%
y = [1,2,3,4,5]

# %%
for i in y:
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in y:
    print (i)
    if i == 3:
        break
# Out:
# 1
# 2
# 3

# %%
for i in "Hello world":
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %% [markdown]
# ## While loop

# %%
x = 1 
y = 1

# %%
while x <10:
    print (x)
    x= x + 1

# %%
while x <10:
    print (x)
    x= x + 1
    if x == 5: 
        continue
# Out:
# 5
# 6
# 7
# 8
# 9
